# %% [markdown]
# Libraries

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# Network Architecture

# %%
activation_map = {

    'tanh' : nn.Tanh(),
    'relu' :  nn.ReLU(),
    'sigmoid' : nn.Sigmoid(),
    'none' : None,
    'None': None

}


class PINNet(nn.Module):
    def __init__(self, layers, activation):
        super().__init__()
        if len(activation)==len(layers):
            layer_list=[]
            activation_model= [activation_map[act] for act in activation]
            for i in range(1, len(activation)):
                layer_list.append(nn.Linear(layers[i-1], layers[i]))
                if activation_model[i] is not None:
                    layer_list.append(activation_model[i])

            self.network = nn.Sequential(*layer_list)

    def forward(self,*args):
        out = torch.cat(args, dim=1)
        return self.network(out)

# %% [markdown]
# Optimizer Functions

# %%
def optimizer(opt, parameters, lr):

    optima= getattr(torch.optim, opt)
    optimize = optima(parameters, lr=lr)

    return optimize

# %% [markdown]
# Xavier Weight Initialization

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

# %% [markdown]
# Gradient Functions

# %%
def grad(y, x):
    return torch.autograd.grad(y, x, grad_outputs=torch.ones_like(y), create_graph=True)[0]

def hessian(y, x):
    z = grad(y, x)
    return torch.autograd.grad(z, x, grad_outputs=torch.ones_like(z), create_graph=True)[0]

# %%
import torch
import os

def save_checkpoint(path, model, optimizer, ic_loss, bc_loss, pde_loss, epoch, loss):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),     
        'optimizer_state_dict': optimizer.state_dict(), 
        'ic_loss': ic_loss,
        'bc_loss': bc_loss,
        'pde_loss': pde_loss,
        'loss': loss
    }, path)
    print(f"Checkpoint saved at {path}")

def load_checkpoint(path, model, optimizer):
    if not os.path.exists(path):
        print(f" No checkpoint found at {path}, starting fresh.")
        return 0, float('inf')

    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    print(f" Loaded checkpoint from epoch {checkpoint['epoch']} with loss {checkpoint['loss']:.4e}")
    return checkpoint['epoch'], checkpoint['loss']

# %% [markdown]
# Diffusivity (piecewise)

# %%
t_time =408
def time_dependent_theta(z, t):
    t_hours = t*t_time
    # Base value
    theta1 = 0.22
    theta2 = 0.18
    base_theta =torch.where(z <= 0.25, theta1, theta2)
    variation = 0.05 * torch.sin(2 * np.pi * t_hours / 24)  # Daily cycle
    return base_theta + variation

def diffusivity(z, t):
    theta = time_dependent_theta(z, t)
    theta_percent = theta * 100
    alpha_1 = 0.23 + 0.25 / (1 + torch.exp(-0.78 * (theta_percent - 11.3)))
    alpha_2 = 0.25 + 0.64 / (1 + torch.exp(-1.72 * (theta_percent - 6.01)))
    alpha_mm2s = torch.where(z <= 0.25,  alpha_1, alpha_2 )
    
    return alpha_mm2s * 1e-6  # Convert mm²/s to m²/s

def heat_source(x, t):
    Area = 2
    depth =0.02
    t_cap = 1800*800*Area*depth
    Q1 = 50 / t_cap   # scaled heat source
    Q2 = 30 / t_cap
    Q3 = 10 / t_cap 
    Q_layer = torch.where((x>=0.84)&(x<0.86), torch.ones_like(x), torch.zeros_like(x))  
    Q_on = torch.where(
        t <= (3/17), Q1*torch.ones_like(t), 
        torch.where(
            (t>=7/17)&(t<=10/17), Q2*torch.ones_like(t), 
            torch.where(
                (t>=14/17)&(t<=1), Q3*torch.ones_like(t), 
                torch.zeros_like(t)
            )
        )
    )
    return Q_layer*Q_on

# %% [markdown]
# Input

# %%
z_min, z_max = 0.0, 0.95
t_min, t_max = 0.0, 1.0
T0 = 18.0  # initial temp

N_f = 10000
z_f = torch.rand((N_f,1))*0.95
t_f = torch.rand((N_f,1))

N_ic = 200
z_ic = torch.rand((N_ic,1))*0.95
t_ic = torch.zeros_like(z_ic)
T_ic = torch.ones_like(z_ic) * T0

N_bc = 200
z_bc_top = torch.zeros((N_bc//2,1))
t_bc_top = torch.rand((N_bc//2,1))
T_bc_top = torch.ones((N_bc//2,1))* T0

z_bc_bot = torch.ones((N_bc//2,1))*0.95
t_bc_bot = torch.rand((N_bc//2,1))
T_bc_bot = torch.zeros((N_bc//2,1))

# %% [markdown]
# Loss Function

# %%
# PDE residual
def pde_residual(model, x, t):
    x.requires_grad = True
    t.requires_grad = True
    tau = 408*3600
    T = model(x, t)
    T_t = grad(T, t)
    T_xx = hessian(T, x)
    alpha = diffusivity(x, t)
    Q = heat_source(x, t)
    
    pde_loss = torch.mean(((T_t - tau*(alpha * T_xx + Q))**2))
    return pde_loss

# %%
def ic_loss(model, x0, t0, T0):
    return torch.mean((model(x0, t0) - T0) ** 2)

# %%
def bc_loss_top(model, x_b, t_b, T_top):
    x_b.requires_grad_(True)
    t_b.requires_grad_(True)
    T = model(x_b, t_b)
    return torch.mean((T- T_top) ** 2)

# %%
def bc_loss(model, x_b, t_b):
    x_b.requires_grad_(True)
    t_b.requires_grad_(True)
    T = model(x_b, t_b)
    T_x = grad(T, x_b)
    return torch.mean(T_x ** 2)

# %%
def loss_function(model, x0, t0, T0, x_b0, t_b0, T_top, x_b1, t_b1, x_f, t_f, epoch):
    ic = ic_loss(model, x0, t0, T0)
    bc = bc_loss_top(model, x_b0, t_b0, T_top) + bc_loss(model, x_b1, t_b1)
    pde = pde_residual(model, x_f, t_f)
    total = 10*bc + ic + pde
    return total, ic.item(), bc.item(), pde.item()

# %% [markdown]
# Model Creation

# %%
model = PINNet([2, 64, 64, 64, 64, 64, 64, 1], ['none', 'tanh', 'tanh', 'tanh', 'tanh', 'tanh', 'tanh', 'none'])
model.apply(init_weights)
optim = optimizer('Adam', model.parameters(), lr=0.001)

# %%
checkpoint_path = '/home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth'
start_epoch, best_loss = load_checkpoint(checkpoint_path, model, optim)
# Out:
#  No checkpoint found at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth, starting fresh.

# %%
# Training
epoch_history = []
ic_history = []
bc_history = []
pde_history = []
total_history =[]

for epoch in range(25001):
    optim.zero_grad()
    
    loss, ic, bc, pde  = loss_function(model, z_ic, t_ic, T_ic, z_bc_top, t_bc_top, T_bc_top, z_bc_bot, t_bc_bot, z_f, t_f, epoch)

    loss.backward()
    
    optim.step()

    if (epoch+1)%1000==0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.5e}, PDE: {pde:.5e}, IC: {ic:.5e}, BC: {bc:.5e}")
        epoch_history.append(epoch+1)
        ic_history.append(ic)
        bc_history.append(bc)
        pde_history.append(pde)
        total_history.append(loss.item())
        save_checkpoint(checkpoint_path, model, optim, ic, bc, pde, epoch+1, loss.item())
# Out:
# Epoch 1000, Loss: 2.27796e+03, PDE: 2.23716e+03, IC: 4.98979e+00, BC: 3.58098e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 2000, Loss: 1.70276e+03, PDE: 1.67539e+03, IC: 6.98348e-01, BC: 2.66713e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 3000, Loss: 1.02669e+03, PDE: 1.00238e+03, IC: 3.07050e-01, BC: 2.39955e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 4000, Loss: 1.34134e+03, PDE: 1.32164e+03, IC: 1.19475e-01, BC: 1.95829e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 5000, Loss: 6.63761e+02, PDE: 6.42326e+02, IC: 1.14512e-01, BC: 2.13213e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 6000, Loss: 8.48080e+02, PDE: 8.28201e+02, IC: 2.17739e-01, BC: 1.96610e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 7000, Loss: 5.17781e+02, PDE: 4.99088e+02, IC: 1.71247e-01, BC: 1.85213e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 8000, Loss: 6.56983e+02, PDE: 6.40562e+02, IC: 8.17758e-02, BC: 1.63385e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 9000, Loss: 4.86961e+02, PDE: 4.72831e+02, IC: 4.49837e-02, BC: 1.40853e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 10000, Loss: 4.26404e+02, PDE: 4.15284e+02, IC: 6.58222e-02, BC: 1.10543e+00
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 11000, Loss: 5.32872e+02, PDE: 5.23273e+02, IC: 1.58490e-01, BC: 9.44072e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 12000, Loss: 3.90959e+02, PDE: 3.82484e+02, IC: 2.18400e-01, BC: 8.25622e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 13000, Loss: 5.89341e+02, PDE: 5.81368e+02, IC: 2.59775e-01, BC: 7.71348e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 14000, Loss: 6.11214e+02, PDE: 6.02957e+02, IC: 2.79755e-01, BC: 7.97661e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 15000, Loss: 3.04010e+02, PDE: 2.96496e+02, IC: 3.58879e-01, BC: 7.15582e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 16000, Loss: 2.33536e+02, PDE: 2.26337e+02, IC: 4.00210e-01, BC: 6.79884e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 17000, Loss: 3.34600e+02, PDE: 3.27766e+02, IC: 3.78407e-01, BC: 6.45562e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 18000, Loss: 4.80700e+02, PDE: 4.74155e+02, IC: 3.38796e-01, BC: 6.20623e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 19000, Loss: 3.34261e+02, PDE: 3.28598e+02, IC: 2.98584e-01, BC: 5.36458e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 20000, Loss: 4.64178e+02, PDE: 4.58648e+02, IC: 3.13526e-01, BC: 5.21592e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 21000, Loss: 4.53663e+02, PDE: 4.48133e+02, IC: 2.40241e-01, BC: 5.28958e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 22000, Loss: 1.80417e+02, PDE: 1.75688e+02, IC: 2.18847e-01, BC: 4.51066e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 23000, Loss: 1.91229e+02, PDE: 1.86836e+02, IC: 1.72056e-01, BC: 4.22152e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 24000, Loss: 1.99363e+02, PDE: 1.95149e+02, IC: 1.84116e-01, BC: 4.03024e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth
# Epoch 25000, Loss: 5.24206e+02, PDE: 5.19956e+02, IC: 1.78080e-01, BC: 4.07174e-01
# Checkpoint saved at /home/ug611257/jupyterlab/ground_heat/checkpoint/case_VIII_checkpoint_1.pth

# %%
# Plotting at t = 1.0
x_plot = torch.linspace(0, 1, 200).view(-1, 1)*0.95
t_plot = torch.ones_like(x_plot)
T_pred = model(x_plot, t_plot).detach().cpu().numpy()
x_np = x_plot.cpu().numpy()

# %%
plt.figure(figsize=(8, 5))
plt.plot(x_np, T_pred, label="Predicted Temperature at t = 1")
plt.axvline(x=0.25, color='gray', linestyle='--')
plt.text(0.125, T_pred.max(), 'Layer 1', ha='center')
plt.text(0.6, T_pred.max(), 'Layer 2', ha='center')
plt.xlabel("x")
plt.ylabel("Temperature")
plt.title("Experiment 3: Temperature Profile at t = 1")
plt.legend()
plt.grid(True)
plt.show()

# %%
# --------------------------
# Generate prediction points
# --------------------------
model.eval()
with torch.no_grad():
    n_time = 200
    t_plot = torch.linspace(0,1,n_time).view(-1,1)
    depths = [0.1, 0.3, 0.6, 0.85]  # scaled depths
    T_results = []
    for d in depths:
        z_plot = torch.ones_like(t_plot) * d
        T_pred = model(z_plot, t_plot).cpu().numpy().flatten()
        T_results.append(T_pred)

# Convert time back to hours
t_hours = (t_plot.numpy().flatten() * t_time)

# --------------------------
# Plot
# --------------------------
plt.figure(figsize=(8,6))
for i, d in enumerate([0.1,0.3,0.6,0.85]):
    plt.plot(t_hours, T_results[i], label=f"{d:.2f} m depth")
plt.xlabel("Time [hours]")
plt.ylabel("Temperature [°C]")
plt.title("Soil temperature vs time at multiple depths")
plt.legend()
plt.grid()
plt.show()

# %%
t_plot = torch.linspace(0, 1, 200).view(-1, 1)
x_plot = 0.85*torch.ones_like(t_plot)
T_pred = heat_source(x_plot, t_plot).detach().cpu().numpy()
t_np = t_plot.cpu().numpy()*t_time

# %%
plt.plot(t_np, T_pred, label="Heat")
plt.xlabel("t")
plt.ylabel("Heat")
plt.title("Experiment: Heat Profile")
plt.legend()
plt.grid(True)
plt.show()

# %%
time = torch.linspace(0, 1, 200).view(-1, 1)
z_alpha1 = torch.full((200, 1), 0.1)  # 0.1m (in layer 1)
z_alpha2 = torch.full((200, 1), 0.5)  # 0.5m (in layer 2)
alpha1_pred = diffusivity(z_alpha1, time).detach().cpu().numpy()
alpha2_pred = diffusivity(z_alpha2, time).detach().cpu().numpy()
time_np = time.cpu().numpy()*t_time

# %%
plt.plot(time_np, alpha1_pred, label="Alpha1")
plt.plot(time_np, alpha2_pred, label="Alpha2")
plt.xlabel("t")
plt.ylabel("Heat")
plt.title("Experiment: Heat Profile")
plt.legend()
plt.grid(True)
plt.show()

# %%
theta1_pred = time_dependent_theta(z_alpha1, time).detach().cpu().numpy()
theta2_pred = time_dependent_theta(z_alpha2, time).detach().cpu().numpy()

# %%
plt.plot(time_np, theta1_pred, label="Theta1")
plt.plot(time_np, theta2_pred, label="Theta2")
plt.xlabel("t")
plt.ylabel("Heat")
plt.title("Experiment: Heat Profile")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# time_z = torch.linspace(0, 1, 200).view(-1, 1)
# Temp = temp(time)
# time_znp = time.cpu().numpy()*t_time

# %% [markdown]
# plt.plot(time_znp, Temp, label="Temp")
# plt.xlabel("t")
# plt.ylabel("Heat")
# plt.title("Experiment: Heat Profile")
# plt.legend()
# plt.grid(True)
# plt.show()
